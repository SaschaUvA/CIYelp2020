# %%
import pandas as pd
from pandas import DataFrame
import json
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %%
data_path = './data/cleveland/'
review_file = 'review.json'
business_file = 'business.json'
user_file = 'user.json'

users = load_jsons(data_path, user_file)
reviews = load_jsons(data_path, review_file)
businesses = load_jsons(data_path, business_file)
reviews = reviews.drop(columns = ['review_id', 'useful', 'funny', 'cool', 'text', 'date'])

# %%
good_businesses = list(businesses.loc[businesses['review_count'] >= 300]['business_id'])
good_users = list(users.loc[users['review_count'] >= 4]['user_id'])
    
reviews_good = reviews[reviews['business_id'].isin(good_businesses)]
reviews_best = reviews_good[reviews_good['user_id'].isin(good_users)]

display(reviews_best.head())
# Out:
#                    user_id             business_id  stars
# 2   vDlrf84X8yu-CZ-8isrOSw  anzCdD5eIEHwydTpXhLlUA    4.0
# 11  kZGPhhKHP-ziJ5ve7k08ew  vdloJPM3bSpQTMlwdFek2A    3.0
# 12  YU9z6RBQTOg-ZuM9ADPwFw  vdloJPM3bSpQTMlwdFek2A    4.0
# 17  TfmeVvNr5MiXaJDV9IdULA  vdloJPM3bSpQTMlwdFek2A    4.0
# 37  RlpkcJqctkKXl-LO1IAtig  5VXxZIMgoKRWbNa6x9kMfw    4.0

# %%
def data_split(data, d = 0.8):
    np.random.seed(seed=5)
    test = np.random.rand(data.shape[0]) < d
    return data[test], data[~test] 

training_set, test_set = data_split(reviews_best)

# %%
def pivot_ratings(reviews):
    """ takes a rating table as input and computes the utility matrix """
    utility_df = reviews.pivot_table(index='business_id', columns='user_id', values='stars')
    return utility_df   

utility_matrix = pivot_ratings(training_set)
display(utility_matrix.head(10))
# Out:
# user_id                 --Awhttr0FhVud5prVpVlA  --_nP6G2mAHyrEFtIG6ggw  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 --amZ_cR9Zgu4B1RrAHJyA  -0Xu57zrI3Rxi8wGZsnWKQ  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     4.0                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     4.0                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 -0x2ov-qcCopv32Imm-TYg  -15vBHK0n-ejyxY418MvHA  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 -1gsm9r8FAvnbbio8mz0sw  -1kZ1AjX3ycFVRllm7BCDg  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 -2R-JDElzGX-jCJKNWCMaQ  -2p_A5675Eh6gcZIGkf2Yw  ...  \
# business_id                                                             ...
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN  ...
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN  ...
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN  ...
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN  ...
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN  ...
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN  ...
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN  ...
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN  ...
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN  ...
# C6cZf419zes2W1S7MfRV6A                     3.0                     NaN  ...
#
# user_id                 zvoKQvcCsnJeC7ZRKrsWPA  zw6YMjaWYgpe0PQQfJbOkg  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     4.0                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 zwCc2g3P6ZgvZ7EvCRWzuA  zwFfSeQoLaeWUptFoo_hOA  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 zxA6KTqMirq7EsaIH93LSA  zxF7vwh32ccSN3CbCMlalw  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     5.0                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     4.0
#
# user_id                 zxL2Wdz18-Op_fBOSYEhuA  zxRHyxQm-32j5Z7Pi7bHCA  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     5.0
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     NaN
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# user_id                 zxmQgVo3BJxHxpRqGQZJgA  zyrsLcN4dyRaySc257MsaQ
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                     NaN                     NaN
# 1gQrMs-I8oKg2p-iRxznzQ                     NaN                     NaN
# 1veVZUawy7IhIc5oDpRRQA                     NaN                     NaN
# 4IGaWH9jUYMtP2uHIFEqFQ                     NaN                     NaN
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN                     NaN
# 9LAXz_VfATZ0kLdaavkN4g                     NaN                     NaN
# 9SrZRDl7-ZfuENCo0DjfsQ                     NaN                     NaN
# AbPQf-X7awuPFDULiJ43bg                     NaN                     5.0
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                     NaN
# C6cZf419zes2W1S7MfRV6A                     NaN                     NaN
#
# [10 rows x 10544 columns]

# %%
"""Filter out users that are in testset but not in trainingset"""
test_users = set(test_set['user_id'])
training_users = set(training_set['user_id'])
drop_users = test_users - training_users
test_set = test_set[~test_set['user_id'].isin(drop_users)]

# %%
def pearson(matrix, id1, id2):
    """Compute pearson."""    
    selected_features = matrix.loc[id1].notna() & matrix.loc[id2].notna()
    
    if not selected_features.any():
        return np.nan
    
    features1 = matrix.loc[id1][selected_features]
    features2 = matrix.loc[id2][selected_features]
    
    return sp.stats.pearsonr(features1, features2)[0]

# %%
def create_similarity_matrix_pearson(matrix):
    """creates the similarity matrix based on pearson correlation."""
    similarity_matrix = pd.DataFrame(0, index=matrix.index, columns=matrix.index, dtype=float)
    
    for business_id in similarity_matrix.index:
        for business_id2 in similarity_matrix.columns:
            similarity_matrix.at[business_id, business_id2] = pearson(matrix, business_id, business_id2)
    
    return similarity_matrix

similarity = create_similarity_matrix_pearson(utility_matrix)
display(similarity.head(20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:3399: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# business_id             -Eu04UHRqmGGyvYRDY8-tg  1gQrMs-I8oKg2p-iRxznzQ  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                1.000000                0.498330
# 1gQrMs-I8oKg2p-iRxznzQ                0.498330                1.000000
# 1veVZUawy7IhIc5oDpRRQA                0.016600               -0.530991
# 4IGaWH9jUYMtP2uHIFEqFQ                0.327047                0.128217
# 5VXxZIMgoKRWbNa6x9kMfw                0.105538                0.187408
# 9LAXz_VfATZ0kLdaavkN4g                0.156269                0.161527
# 9SrZRDl7-ZfuENCo0DjfsQ                0.511981               -0.443188
# AbPQf-X7awuPFDULiJ43bg                0.380318               -0.106998
# AwlvIsKDqB5LeKNWC6k4kQ                0.364066                0.642639
# C6cZf419zes2W1S7MfRV6A                0.206587               -0.052414
# F2pfjAZ_3dMTGCKv6c5wOw                0.295837                0.132052
# GIfZNMP0oIJCje_Xp0Bgrw                0.054972               -0.058183
# HNs2Nf-trqFTDtho4vhfmA                0.223170               -0.283192
# J1RDyyPxhioqm8c_fi4P4Q                0.205287                0.260827
# JezHN-9KKLTMbojq00VP0g               -0.109678                0.191631
# K6fYrrTorlpXmqutRcrHzg                0.427867               -0.069385
# L7txS44bvz862djgTOim9w                0.220606                0.235525
# LNsZJP6jZ11e0tDljOLPiQ                0.106602                0.320211
# OA5Li3ySzhrbG_WvD_QGYA                0.524912                0.177199
# OD2dbQTKN7FS01fHzZqqzA                0.084085               -0.250302
#
# business_id             1veVZUawy7IhIc5oDpRRQA  4IGaWH9jUYMtP2uHIFEqFQ  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg            1.659994e-02                0.327047
# 1gQrMs-I8oKg2p-iRxznzQ           -5.309908e-01                0.128217
# 1veVZUawy7IhIc5oDpRRQA            1.000000e+00                0.541514
# 4IGaWH9jUYMtP2uHIFEqFQ            5.415139e-01                1.000000
# 5VXxZIMgoKRWbNa6x9kMfw           -3.737175e-01                0.129619
# 9LAXz_VfATZ0kLdaavkN4g           -3.042903e-01                0.638112
# 9SrZRDl7-ZfuENCo0DjfsQ            8.304548e-02               -0.126653
# AbPQf-X7awuPFDULiJ43bg            1.409513e-01                0.317144
# AwlvIsKDqB5LeKNWC6k4kQ           -1.944867e-01                0.035429
# C6cZf419zes2W1S7MfRV6A           -1.387779e-17                0.042112
# F2pfjAZ_3dMTGCKv6c5wOw           -3.000150e-02                0.280315
# GIfZNMP0oIJCje_Xp0Bgrw           -3.743148e-02                0.402152
# HNs2Nf-trqFTDtho4vhfmA           -7.845987e-02                0.003946
# J1RDyyPxhioqm8c_fi4P4Q            3.149704e-01               -0.039898
# JezHN-9KKLTMbojq00VP0g           -1.137874e-01                0.398728
# K6fYrrTorlpXmqutRcrHzg            2.175394e-01                0.452087
# L7txS44bvz862djgTOim9w            2.328816e-01                0.802256
# LNsZJP6jZ11e0tDljOLPiQ            2.031627e-01                0.227569
# OA5Li3ySzhrbG_WvD_QGYA            4.610694e-03               -0.065739
# OD2dbQTKN7FS01fHzZqqzA            3.125000e-01                0.174218
#
# business_id             5VXxZIMgoKRWbNa6x9kMfw  9LAXz_VfATZ0kLdaavkN4g  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg            1.055384e-01                0.156269
# 1gQrMs-I8oKg2p-iRxznzQ            1.874083e-01                0.161527
# 1veVZUawy7IhIc5oDpRRQA           -3.737175e-01               -0.304290
# 4IGaWH9jUYMtP2uHIFEqFQ            1.296190e-01                0.638112
# 5VXxZIMgoKRWbNa6x9kMfw            1.000000e+00                0.126211
# 9LAXz_VfATZ0kLdaavkN4g            1.262109e-01                1.000000
# 9SrZRDl7-ZfuENCo0DjfsQ           -6.859943e-01               -0.250801
# AbPQf-X7awuPFDULiJ43bg           -7.922523e-02               -0.026343
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN                0.319438
# C6cZf419zes2W1S7MfRV6A            1.197798e-01                0.102062
# F2pfjAZ_3dMTGCKv6c5wOw           -1.013594e-01                0.428416
# GIfZNMP0oIJCje_Xp0Bgrw           -1.280894e-02               -0.056167
# HNs2Nf-trqFTDtho4vhfmA           -3.006717e-01                0.222807
# J1RDyyPxhioqm8c_fi4P4Q           -7.488379e-03                0.319619
# JezHN-9KKLTMbojq00VP0g           -1.387779e-17                0.222222
# K6fYrrTorlpXmqutRcrHzg           -1.208371e-01                0.188377
# L7txS44bvz862djgTOim9w            4.097645e-01                0.794118
# LNsZJP6jZ11e0tDljOLPiQ            2.251672e-01               -0.076283
# OA5Li3ySzhrbG_WvD_QGYA            3.889609e-01                0.380775
# OD2dbQTKN7FS01fHzZqqzA            1.463571e-01               -0.287182
#
# business_id             9SrZRDl7-ZfuENCo0DjfsQ  AbPQf-X7awuPFDULiJ43bg  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.511981            3.803179e-01
# 1gQrMs-I8oKg2p-iRxznzQ               -0.443188           -1.069981e-01
# 1veVZUawy7IhIc5oDpRRQA                0.083045            1.409513e-01
# 4IGaWH9jUYMtP2uHIFEqFQ               -0.126653            3.171442e-01
# 5VXxZIMgoKRWbNa6x9kMfw               -0.685994           -7.922523e-02
# 9LAXz_VfATZ0kLdaavkN4g               -0.250801           -2.634317e-02
# 9SrZRDl7-ZfuENCo0DjfsQ                1.000000           -1.936492e-01
# AbPQf-X7awuPFDULiJ43bg               -0.193649            1.000000e+00
# AwlvIsKDqB5LeKNWC6k4kQ                0.377964           -7.933288e-02
# C6cZf419zes2W1S7MfRV6A               -0.081111            8.416254e-01
# F2pfjAZ_3dMTGCKv6c5wOw                0.253368            1.100101e-01
# GIfZNMP0oIJCje_Xp0Bgrw               -0.155002            1.193349e-01
# HNs2Nf-trqFTDtho4vhfmA                0.265930           -2.440731e-01
# J1RDyyPxhioqm8c_fi4P4Q                0.598912            1.387779e-17
# JezHN-9KKLTMbojq00VP0g                0.198030           -1.381279e-01
# K6fYrrTorlpXmqutRcrHzg                0.061012            1.982586e-01
# L7txS44bvz862djgTOim9w               -0.302614           -2.309879e-01
# LNsZJP6jZ11e0tDljOLPiQ                0.394672            8.101000e-02
# OA5Li3ySzhrbG_WvD_QGYA                0.299504            3.224223e-01
# OD2dbQTKN7FS01fHzZqqzA                0.538816            4.364358e-01
#
# business_id             AwlvIsKDqB5LeKNWC6k4kQ  C6cZf419zes2W1S7MfRV6A  ...  \
# business_id                                                             ...
# -Eu04UHRqmGGyvYRDY8-tg                0.364066            2.065870e-01  ...
# 1gQrMs-I8oKg2p-iRxznzQ                0.642639           -5.241424e-02  ...
# 1veVZUawy7IhIc5oDpRRQA               -0.194487           -1.387779e-17  ...
# 4IGaWH9jUYMtP2uHIFEqFQ                0.035429            4.211174e-02  ...
# 5VXxZIMgoKRWbNa6x9kMfw                     NaN            1.197798e-01  ...
# 9LAXz_VfATZ0kLdaavkN4g                0.319438            1.020621e-01  ...
# 9SrZRDl7-ZfuENCo0DjfsQ                0.377964           -8.111071e-02  ...
# AbPQf-X7awuPFDULiJ43bg               -0.079333            8.416254e-01  ...
# AwlvIsKDqB5LeKNWC6k4kQ                1.000000           -9.176801e-02  ...
# C6cZf419zes2W1S7MfRV6A               -0.091768            1.000000e+00  ...
# F2pfjAZ_3dMTGCKv6c5wOw                0.103606           -1.128687e-01  ...
# GIfZNMP0oIJCje_Xp0Bgrw                0.155749           -7.508035e-02  ...
# HNs2Nf-trqFTDtho4vhfmA               -0.372104            4.187750e-01  ...
# J1RDyyPxhioqm8c_fi4P4Q                0.413290            1.148129e-01  ...
# JezHN-9KKLTMbojq00VP0g                0.189574           -2.603778e-01  ...
# K6fYrrTorlpXmqutRcrHzg               -0.115190           -1.039402e-01  ...
# L7txS44bvz862djgTOim9w                     NaN            5.000000e-01  ...
# LNsZJP6jZ11e0tDljOLPiQ                0.074371            2.759098e-01  ...
# OA5Li3ySzhrbG_WvD_QGYA                     NaN            5.758168e-01  ...
# OD2dbQTKN7FS01fHzZqqzA                     NaN           -2.258065e-01  ...
#
# business_id             knJh7agyWMdPyndI9dURjw  meXjqyhTNLFmknY39y2sMg  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.096395            1.267501e-01
# 1gQrMs-I8oKg2p-iRxznzQ                0.119979           -1.394601e-01
# 1veVZUawy7IhIc5oDpRRQA               -0.185129            1.881442e-01
# 4IGaWH9jUYMtP2uHIFEqFQ                0.296833           -2.308670e-01
# 5VXxZIMgoKRWbNa6x9kMfw               -0.267261           -2.479344e-01
# 9LAXz_VfATZ0kLdaavkN4g                0.234738            5.204170e-18
# 9SrZRDl7-ZfuENCo0DjfsQ                0.675897           -2.913737e-02
# AbPQf-X7awuPFDULiJ43bg               -0.225723           -1.672692e-01
# AwlvIsKDqB5LeKNWC6k4kQ                     NaN           -3.464626e-01
# C6cZf419zes2W1S7MfRV6A                0.011835           -1.029421e-01
# F2pfjAZ_3dMTGCKv6c5wOw               -0.438579            1.597185e-01
# GIfZNMP0oIJCje_Xp0Bgrw               -0.081284            1.173675e-02
# HNs2Nf-trqFTDtho4vhfmA                0.021077            3.204830e-01
# J1RDyyPxhioqm8c_fi4P4Q               -0.150269           -8.239619e-02
# JezHN-9KKLTMbojq00VP0g               -0.132453           -2.082279e-02
# K6fYrrTorlpXmqutRcrHzg                0.326476            1.314436e-01
# L7txS44bvz862djgTOim9w                0.091670           -2.009191e-01
# LNsZJP6jZ11e0tDljOLPiQ                0.064440            8.992033e-02
# OA5Li3ySzhrbG_WvD_QGYA                0.298807           -2.122711e-01
# OD2dbQTKN7FS01fHzZqqzA                0.353553           -1.425665e-01
#
# business_id             nJrFxROYx9sis3acKkhzgA  orrrhqRRUORIzUSxWTveKg  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.042454                0.257455
# 1gQrMs-I8oKg2p-iRxznzQ               -0.114885                0.474342
# 1veVZUawy7IhIc5oDpRRQA               -0.210408                0.027864
# 4IGaWH9jUYMtP2uHIFEqFQ               -0.353914                0.049507
# 5VXxZIMgoKRWbNa6x9kMfw                0.175250                0.188422
# 9LAXz_VfATZ0kLdaavkN4g               -1.000000                0.500000
# 9SrZRDl7-ZfuENCo0DjfsQ                0.904534               -0.408248
# AbPQf-X7awuPFDULiJ43bg                0.007083                0.179100
# AwlvIsKDqB5LeKNWC6k4kQ                0.380521                0.288926
# C6cZf419zes2W1S7MfRV6A                0.297536                0.126189
# F2pfjAZ_3dMTGCKv6c5wOw                0.256990                0.175484
# GIfZNMP0oIJCje_Xp0Bgrw                0.369121                0.115877
# HNs2Nf-trqFTDtho4vhfmA                0.531118                0.332448
# J1RDyyPxhioqm8c_fi4P4Q                0.283322                0.374766
# JezHN-9KKLTMbojq00VP0g                0.248317                0.333333
# K6fYrrTorlpXmqutRcrHzg                0.241777                0.238350
# L7txS44bvz862djgTOim9w                0.025252                0.209657
# LNsZJP6jZ11e0tDljOLPiQ               -0.049093                0.020567
# OA5Li3ySzhrbG_WvD_QGYA                0.426690                0.477245
# OD2dbQTKN7FS01fHzZqqzA               -0.166574                0.533002
#
# business_id             oxeW1tSB-e_oIzCQZtqyTw  t2O4Qx74U_IfBzDHJzvUCA  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.278558               -0.141289
# 1gQrMs-I8oKg2p-iRxznzQ                0.125269                0.128008
# 1veVZUawy7IhIc5oDpRRQA                0.398282                0.535899
# 4IGaWH9jUYMtP2uHIFEqFQ                0.285980                0.107770
# 5VXxZIMgoKRWbNa6x9kMfw                0.109904               -0.209409
# 9LAXz_VfATZ0kLdaavkN4g                0.000000               -0.306719
# 9SrZRDl7-ZfuENCo0DjfsQ                0.061113                0.422489
# AbPQf-X7awuPFDULiJ43bg                0.386823               -0.393079
# AwlvIsKDqB5LeKNWC6k4kQ               -0.069737                0.299788
# C6cZf419zes2W1S7MfRV6A               -0.132201               -0.282687
# F2pfjAZ_3dMTGCKv6c5wOw                0.034787               -0.503077
# GIfZNMP0oIJCje_Xp0Bgrw                0.414567                0.294361
# HNs2Nf-trqFTDtho4vhfmA                0.360585                0.013196
# J1RDyyPxhioqm8c_fi4P4Q                0.344407               -0.058612
# JezHN-9KKLTMbojq00VP0g                0.360275               -0.201924
# K6fYrrTorlpXmqutRcrHzg                0.291277                0.175409
# L7txS44bvz862djgTOim9w                0.277984                0.133364
# LNsZJP6jZ11e0tDljOLPiQ                0.048795                0.348289
# OA5Li3ySzhrbG_WvD_QGYA                0.062610                0.180377
# OD2dbQTKN7FS01fHzZqqzA                0.460643                0.147770
#
# business_id             vdloJPM3bSpQTMlwdFek2A  wOKcWLyN1DhSEl3Y1eG5nQ  \
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.067757            1.053544e-01
# 1gQrMs-I8oKg2p-iRxznzQ                0.161120            4.261276e-01
# 1veVZUawy7IhIc5oDpRRQA                0.657895            5.038911e-02
# 4IGaWH9jUYMtP2uHIFEqFQ                0.441250            1.433011e-01
# 5VXxZIMgoKRWbNa6x9kMfw               -0.390578            1.618386e-01
# 9LAXz_VfATZ0kLdaavkN4g               -0.314820           -2.660532e-01
# 9SrZRDl7-ZfuENCo0DjfsQ                0.160615            5.551115e-17
# AbPQf-X7awuPFDULiJ43bg                0.590472            1.124418e-01
# AwlvIsKDqB5LeKNWC6k4kQ                0.555556            9.942416e-02
# C6cZf419zes2W1S7MfRV6A               -0.141189           -5.542223e-01
# F2pfjAZ_3dMTGCKv6c5wOw                0.155847            2.960020e-01
# GIfZNMP0oIJCje_Xp0Bgrw               -0.083914            4.387932e-01
# HNs2Nf-trqFTDtho4vhfmA               -0.155976            1.747334e-01
# J1RDyyPxhioqm8c_fi4P4Q                0.308171            5.788135e-02
# JezHN-9KKLTMbojq00VP0g               -0.176090            3.715417e-01
# K6fYrrTorlpXmqutRcrHzg               -0.603602            1.819046e-01
# L7txS44bvz862djgTOim9w               -0.516047            3.275555e-01
# LNsZJP6jZ11e0tDljOLPiQ                0.216583            8.000361e-02
# OA5Li3ySzhrbG_WvD_QGYA                0.151744           -2.043174e-01
# OD2dbQTKN7FS01fHzZqqzA                0.111054           -7.866782e-02
#
# business_id             wib5LeUWBkxu67Rl3ruMDQ  xfCgxY_SQfzxFsQjNiLJEQ
# business_id
# -Eu04UHRqmGGyvYRDY8-tg                0.046338                0.312561
# 1gQrMs-I8oKg2p-iRxznzQ               -0.381605                0.312250
# 1veVZUawy7IhIc5oDpRRQA               -0.189189               -0.267261
# 4IGaWH9jUYMtP2uHIFEqFQ                0.229129               -0.557086
# 5VXxZIMgoKRWbNa6x9kMfw                0.037857               -0.165570
# 9LAXz_VfATZ0kLdaavkN4g                0.267679               -0.363175
# 9SrZRDl7-ZfuENCo0DjfsQ               -0.191023                0.395285
# AbPQf-X7awuPFDULiJ43bg                0.391293                0.254824
# AwlvIsKDqB5LeKNWC6k4kQ                0.603222                0.377676
# C6cZf419zes2W1S7MfRV6A                0.126323               -0.133950
# F2pfjAZ_3dMTGCKv6c5wOw                0.185491                0.076249
# GIfZNMP0oIJCje_Xp0Bgrw                0.227056               -0.139625
# HNs2Nf-trqFTDtho4vhfmA                0.281975               -0.419371
# J1RDyyPxhioqm8c_fi4P4Q               -0.343081                0.069589
# JezHN-9KKLTMbojq00VP0g                0.368562               -0.019462
# K6fYrrTorlpXmqutRcrHzg                0.316323               -0.274024
# L7txS44bvz862djgTOim9w                0.388519                     NaN
# LNsZJP6jZ11e0tDljOLPiQ                0.082033                0.293293
# OA5Li3ySzhrbG_WvD_QGYA               -0.014838               -0.052868
# OD2dbQTKN7FS01fHzZqqzA               -0.029792                0.531816
#
# [20 rows x 47 columns]

# %%
def select_neighborhood(similarities, ratings, k):
    """ selects all items with similarity > 0  """
    positive_similarities = similarities[similarities > 0]
    ratings = ratings.dropna()
    common = positive_similarities.index.intersection(ratings.index)
    
    return positive_similarities.loc[common].nlargest(k)

# %%
def weighted_mean(neighborhood, ratings):
    if neighborhood.empty:     
        return np.nan
    
    weight = neighborhood * ratings
    weight = weight.dropna()
    
    return weight.sum()/neighborhood.sum()

# %%
def predict_ratings_item_based(similarity, utility, user_item_pairs):
    similarity_test = user_item_pairs.copy()
    
    predictions = [weighted_mean(select_neighborhood(similarity[business_id], utility[user_id], 100), utility[user_id]) 
                   for user_id, business_id in zip(similarity_test['user_id'], similarity_test['business_id'])]
    
    similarity_test['predicted rating'] = predictions
    
    return similarity_test
    

predicted_item_based = predict_ratings_item_based(similarity, utility_matrix, test_set[['business_id', 'user_id', 'stars']])
predicted_item_based = predicted_item_based.dropna()
display(predicted_item_based.head(25))
# Out:
#                 business_id                 user_id  stars  predicted rating
# 11   vdloJPM3bSpQTMlwdFek2A  kZGPhhKHP-ziJ5ve7k08ew    3.0          3.110750
# 191  anzCdD5eIEHwydTpXhLlUA  QS2fLDJTylluRXUTmHiY3w    5.0          4.580963
# 202  vdloJPM3bSpQTMlwdFek2A  Ghb0s3rnXfHZ4GjAklf-tw    2.0          3.000000
# 269  vdloJPM3bSpQTMlwdFek2A  oAil_gYOXUhqWnKA8SwKsw    3.0          4.178999
# 281  5VXxZIMgoKRWbNa6x9kMfw  PrwnAL82LL4Ewt_wJpHWCA    5.0          3.348688
# 289  anzCdD5eIEHwydTpXhLlUA  F-xATFSnMeDKy7Xkfz_Ujw    5.0          5.000000
# 300  vdloJPM3bSpQTMlwdFek2A  sxEzazybwfF86Mv8Dm3tgw    4.0          5.000000
# 344  anzCdD5eIEHwydTpXhLlUA  RSAHZjr2yPZHZ-HhrgCrXQ    5.0          4.616966
# 373  anzCdD5eIEHwydTpXhLlUA  qn7SAaO9Jwl2ls5c9Og2yA    5.0          2.000000
# 391  vdloJPM3bSpQTMlwdFek2A  8ovJHI-LlBXozwHceNMHAA    5.0          4.000000
# 448  vdloJPM3bSpQTMlwdFek2A  pOHkwKuw-W9NyuaC0Z_k_Q    5.0          4.000000
# 450  VH2BjFjc9usDquDgoHhptA  sxEzazybwfF86Mv8Dm3tgw    4.0          3.546996
# 486  VH2BjFjc9usDquDgoHhptA  8AIrfpqWl_O4vX1mEzETeg    3.0          4.000000
# 501  VH2BjFjc9usDquDgoHhptA  3NcvQhYiC0jUblVfF6PUeQ    4.0          4.356805
# 515  anzCdD5eIEHwydTpXhLlUA  7nRSU71S8mTjFOjc7ztcJQ    5.0          5.000000
# 529  VH2BjFjc9usDquDgoHhptA  Qxlqs1O-T2Cb2bNGWMZ8bg    2.0          3.054474
# 559  anzCdD5eIEHwydTpXhLlUA  zISSIzkNWqBlPfZ_YvWD1A    4.0          4.357937
# 573  VH2BjFjc9usDquDgoHhptA  -qvT_R8tMwqx1FYsi4BkfQ    5.0          4.024186
# 622  VH2BjFjc9usDquDgoHhptA  UO5zF-_vXZcpUwDNZpRmAQ    4.0          4.000000
# 674  VH2BjFjc9usDquDgoHhptA  u2DMRWzZbDs_WNlVni5ogQ    5.0          5.000000
# 724  vdloJPM3bSpQTMlwdFek2A  42XZNMnktSgJnowEHOYPuQ    5.0          4.000000
# 733  5VXxZIMgoKRWbNa6x9kMfw  oTae-gLGMpNNFxcBn2D77A    3.0          4.744290
# 791  VH2BjFjc9usDquDgoHhptA  imBfIJm85WkcD3xKUOaAAA    5.0          4.435961
# 801  anzCdD5eIEHwydTpXhLlUA  GWaGs0r0fliNU6xcyQhGSA    5.0          4.406868
# 804  VH2BjFjc9usDquDgoHhptA  aDecXrigIQ7DGIVu8j7EYw    5.0          4.573842

# %%
def mse(predicted_ratings):
    boven_deelstreep = sum((predicted_ratings['stars'] - predicted_ratings['predicted rating'])**2)
    return boven_deelstreep / len(predicted_ratings)
    
mse_item_based = mse(predicted_item_based.dropna())

# %%
predicted_random = test_set.copy()[['user_id', 'business_id', 'stars']]
predicted_random['predicted rating'] = np.random.uniform(low=0.5, high=5.0, size=len(predicted_random))
mse_random = mse(predicted_random)

# %%
predicted_item_mean = test_set.copy()[['user_id', 'business_id', 'stars']]
grouped = predicted_item_mean.groupby('business_id')
grouped_means = grouped.aggregate(np.mean)

joined = predicted_item_mean.set_index('business_id').join(grouped_means, rsuffix='mean')
predicted_item_mean = joined.rename(columns={'starsmean': 'predicted rating'})

mse_item_mean = mse(predicted_item_mean)

print(f'mse for item based prediction: {mse_item_based:.2f}')
print(f'mse for random prediction: {mse_random:.2f}')
print(f'mse for mean per item: {mse_item_mean:.2f}')
# Out:
# mse for item based prediction: 1.69
# mse for random prediction: 4.30
# mse for mean per item: 1.02

# %%
'''
HELPER FUNCTIONS
'''


def recommended(predictions, treshold):
    return predictions.loc[predictions['predicted rating'] >= treshold]
    

def hidden(predictions, treshold):
    return predictions.loc[predictions['predicted rating'] < treshold]


def used(predictions, treshold):
    return predictions.loc[predictions['stars'] >= treshold]
    

def unused(predictions, treshold):
    return predictions.loc[predictions['stars'] < treshold]


def confusion(recommended, hidden, used, unused):
    true_pos = len(recommended.join(used, rsuffix='_used').dropna())
    false_pos = len(recommended.join(unused, rsuffix='_unused').dropna())
    true_neg = len(hidden.join(unused, rsuffix='_unused').dropna())
    false_neg = len(hidden.join(used, rsuffix='_used').dropna())
    confusion_matrix = pd.DataFrame({'used': [true_pos, false_neg], 'unused': [false_pos, true_neg]}, 
                                 index=['recommended', 'hidden'],)
    return confusion_matrix


def precision(confusion_matrix):
    true_pos = confusion_matrix.iloc[0,0]
    false_pos = confusion_matrix.iloc[0,1]
    return true_pos / (true_pos + false_pos)


def recall(confusion_matrix):
    true_pos = confusion_matrix.iloc[0,0]
    false_neg = confusion_matrix.iloc[1,0]
    return true_pos / (true_pos + false_neg)

# %%
threshold_used = 3.75
threshold_recommended = [2.5, 3.0, 3.5, 4.0, 4.5]


def precisionRecallCurve(matrix, treshold_recommended):
    recommended_matrix = recommended(matrix, treshold_recommended)
    hidden_matrix = hidden(matrix, treshold_recommended)
    used_matrix = used(matrix, threshold_used)
    unused_matrix = unused(matrix, threshold_used)
    confusion_matrix = confusion(recommended_matrix, hidden_matrix, used_matrix, unused_matrix)
    precision_matrix = precision(confusion_matrix)
    recall_matrix = recall(confusion_matrix)
    return (precision_matrix, recall_matrix)



# collaborative filtering
collab_pc = []
collab_rc = []
collab_f1 = []
for threshold in threshold_recommended:
    collab_results = precisionRecallCurve(predicted_item_based, threshold)
    prec = collab_results[0]
    rec = collab_results[1]
    collab_f1.append(2 * ((prec * rec) / (prec + rec)))
    collab_pc.append(prec)
    collab_rc.append(rec)

# plot collab
precisions_collab = collab_pc
recalls_collab = collab_rc
plt.plot(recalls_collab, precisions_collab)
for r, p, t in zip(recalls_collab, precisions_collab, threshold_recommended):
    plt.text(r, p, t)   
    
    

# random
random_pc = []
random_rc = []
random_f1 = []
for threshold in threshold_recommended:
    random_results = precisionRecallCurve(predicted_random, threshold)
    prec = random_results[0]
    rec = random_results[1]
    random_f1.append(2 * ((prec * rec) / (prec + rec)))
    random_pc.append(prec)
    random_rc.append(rec)

# plot random
precisions_random = random_pc
recalls_random = random_rc
plt.plot(recalls_random, precisions_random)
for r, p, t in zip(recalls_random, precisions_random, threshold_recommended):
    plt.text(r, p, t)  



# mean
mean_pc = []
mean_rc = []
mean_f1 = []
for threshold in threshold_recommended:
    mean_results = precisionRecallCurve(predicted_item_mean, threshold)
    prec = mean_results[0]
    rec = mean_results[1]
    mean_f1.append(2 * ((prec * rec) / (prec + rec)))
    mean_pc.append(prec)
    mean_rc.append(rec)

# plot mean
precisions_mean = mean_pc
recalls_mean = mean_rc
plt.plot(recalls_mean, precisions_mean)
for r, p, t in zip(recalls_mean, precisions_mean, threshold_recommended):
    plt.text(r, p, t)  



plt.xlim(0.0, 1.0)
plt.ylim(0.3, 1.0)
plt.xlabel('recall')
plt.ylabel('precision')

plt.legend(['item_based', 'random', 'mean'], loc = 'lower left')

# %%
plt.plot(threshold_recommended, mean_f1)
plt.plot(threshold_recommended, random_f1)
plt.plot(threshold_recommended, collab_f1)

for r, f in zip(threshold_recommended, collab_f1):
    plt.text(r, f, round(f, 2))  

for r, f in zip(threshold_recommended, mean_f1):
    plt.text(r, f, round(f, 2))  
    
for r, f in zip(threshold_recommended, random_f1):
    plt.text(r, f, round(f, 2))  
    

plt.ylabel('f1-score')
plt.xlabel('threshold_recommended')

plt.ylim(0, 1)

plt.legend(['item_based', 'random', 'mean'], loc = 'lower left')
